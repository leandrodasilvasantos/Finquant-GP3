# %%
import pandas as pd
import numpy as np

# %%
cpi = pd.read_csv('cpi.csv')
fx = pd.read_csv('fx.csv')
rates = pd.read_csv('rates.csv')

display(cpi.head())
display(fx.head())
display(rates.head())
# Out:
#    Estados Unidos    Europa  Reino Unido     Japao     China     Suica  \
# 0        1.000000  1.000000     1.000000  1.000000  1.000000  1.000000
# 1        1.000331  1.010996     1.004494  1.002108  0.992949  1.001370
# 2        1.000561  1.015133     1.010112  1.002108  0.994975  1.009929
# 3        1.000041  1.016331     1.012360  1.002108  0.994002  1.008887
# 4        0.999623  1.016331     1.013483  1.000000  0.988004  1.004494
#
#    Australia    Canada  Coreia do Sul   Noruega    Suecia    Mexico     India  \
# 0   1.000000  1.000000       1.000000  1.000000  1.000000  1.000000  1.000000
# 1   1.000000  1.000000       1.002023  1.005435  1.002395  1.007099  1.000000
# 2   1.006302  1.003460       1.006057  1.007609  1.002528  1.003890  1.000000
# 3   1.006302  1.006055       1.007074  1.002174  1.004391  0.997565  1.011765
# 4   1.006302  1.005190       1.006057  1.001087  1.004557  0.997252  1.023530
#
#      Brasil
# 0  1.000000
# 1  1.005199
# 2  1.010930
# 3  1.015278
# ...
